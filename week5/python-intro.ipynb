# %% [markdown]
# # Python & Jupyter Notebook Basics
# This notebook introduces Python basics for data visualization, and shows how to use Jupyter Notebooks for interactive coding.

# %% [markdown]
# ## What is a Jupyter Notebook?
# A Jupyter Notebook is an interactive coding environment where you can write and run code in small chunks (cells), see the output immediately, and mix code with notes, images, and visualizations. Google Colab is a free, cloud-based version of Jupyter.

# %%
# Print a message (run this cell!)
print("Hello, world! This is Python in a Jupyter Notebook.")

# %% [markdown]
# ## Python Basics: Variables and Lists

# %%
# Variables
x = 5
name = "Matías"

# Lists
numbers = [1, 2, 3, 4, 5]
print("x:", x)
print("name:", name)
print("numbers:", numbers)

# %% [markdown]
# ## Loops and Functions

# %%
# Loop through a list
for n in numbers:
    print("Number:", n)

# Define a function
def square(num):
    return num * num

print("Square of 4:", square(4))

# %% [markdown]
# ## Using Libraries: pandas and matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a simple DataFrame
data = {'name': ['Alice', 'Bob', 'Charlie'], 'score': [85, 92, 78]}
df = pd.DataFrame(data)
print(df)

# Plot a simple bar chart
plt.bar(df['name'], df['score'])
plt.xlabel('Name')
plt.ylabel('Score')
plt.title('Scores by Name')
plt.show()

# %% [markdown]
# ---
#
# Try running and editing the code in each cell. You can also open this notebook in Google Colab for a cloud-based experience!

# %% [markdown]
# # Installing Python Libraries
#
# Before you start coding, you may need to install extra Python libraries (like pandas or matplotlib). You can do this in two ways:
#
# **In the terminal:**
# ```
# pip install pandas matplotlib
# ```
#
# **In a Jupyter notebook cell:**
# ```
# !pip install pandas matplotlib
# ```
#
# Google Colab already has many libraries pre-installed, but you can use the same commands if you need more.
